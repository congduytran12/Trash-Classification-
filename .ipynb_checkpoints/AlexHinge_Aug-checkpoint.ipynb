# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# C:\Users\Duy.TC214885\AppData\Local\miniconda3\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.12.2 when it was built against 1.12.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
cardboard = []
for i in range(1,404):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/cardboard/cardboard"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    cardboard.append(X)
cardboard = np.array(cardboard)
cardboard = np.take(cardboard,np.random.permutation(cardboard.shape[0]),axis=0)
print(cardboard.shape)
# Out:
# (403, 227, 227, 3)

# %%
glass = []
for i in range(1,502):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/glass/glass"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    glass.append(X)
glass = np.array(glass)
glass = np.take(glass,np.random.permutation(glass.shape[0]),axis=0)
print(glass.shape)
# Out:
# (501, 227, 227, 3)

# %%
metal = []
for i in range(1,411):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/metal/metal"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    metal.append(X)
metal = np.array(metal)
metal = np.take(metal,np.random.permutation(metal.shape[0]),axis=0)
print(metal.shape)
# Out:
# (410, 227, 227, 3)

# %%
paper = []
for i in range(1,595):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/paper/paper"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    paper.append(X)
paper = np.array(paper)
paper = np.take(paper,np.random.permutation(paper.shape[0]),axis=0)
print(paper.shape)
# Out:
# (594, 227, 227, 3)

# %%
plastic = []
for i in range(1,483):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/plastic/plastic"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    plastic.append(X)
plastic = np.array(plastic)
plastic = np.take(plastic,np.random.permutation(plastic.shape[0]),axis=0)
print(plastic.shape)
# Out:
# (482, 227, 227, 3)

# %%
trash = []
for i in range(1,138):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/trash/trash"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    trash.append(X)
trash = np.array(trash)
trash = np.take(trash,np.random.permutation(trash.shape[0]),axis=0)
print(trash.shape)
# Out:
# (137, 227, 227, 3)

# %%
train_X = np.vstack((cardboard[:302,:,:,:],glass[:376,:,:,:],metal[:307,:,:,:],
                    paper[:445,:,:,:],plastic[:361,:,:,:],trash[:103,:,:,:]))
test_X = np.vstack((cardboard[302:,:,:,:],glass[376:,:,:,:],metal[307:,:,:,:],
                   paper[445:,:,:,:],plastic[361:,:,:,:],trash[103:,:,:,:]))
train_Y = np.zeros((6,train_X.shape[0]))
test_Y = np.zeros((6,test_X.shape[0]))
for i in range(train_X.shape[0]):
    if(i<302):
        train_Y[0][i] = 1
    elif(i<678):
        train_Y[1][i] = 1
    elif(i<985):
        train_Y[2][i] = 1
    elif(i<1430):
        train_Y[3][i] = 1
    elif(i<1791):
        train_Y[4][i] = 1
    else:
        train_Y[5][i] = 1
for i in range(test_X.shape[0]):
    if(i<101):
        test_Y[0][i] = 1
    elif(i<226):
        test_Y[1][i] = 1
    elif(i<329):
        test_Y[2][i] = 1
    elif(i<478):
        test_Y[3][i] = 1
    elif(i<599):
        test_Y[4][i] = 1
    else:
        test_Y[5][i] = 1

# %%
test_X_re = test_X
test_Y_re = test_Y

# %%
np.random.seed(1013)
train_perm = np.random.permutation(train_X.shape[0])
train_X = np.take(train_X,train_perm,axis=0)
print(train_X.shape)
train_Y = np.take(train_Y,train_perm,axis=1)
print(train_Y.shape)
np.random.seed(901)
test_perm = np.random.permutation(test_X.shape[0])
test_X = np.take(test_X,test_perm,axis=0)
print(test_X.shape)
test_Y = np.take(test_Y,test_perm,axis=1)
print(test_Y.shape)
# Out:
# (1894, 227, 227, 3)
# (6, 1894)
# (633, 227, 227, 3)
# (6, 633)

# %%
train_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    width_shift_range=0.1,height_shift_range=0.1, rotation_range=45, zoom_range=0.1,
    horizontal_flip=True,vertical_flip=True)
train_gen.fit(train_X)

# %%
def AlexNetHinge(input_shape = (227, 227, 3), classes = 6):
    X_input = tf.keras.Input(input_shape)
    X = X_input
    X = tf.keras.layers.Conv2D(96, (11, 11), strides = (4, 4), activation = "relu", name = 'conv1')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = tf.keras.layers.Conv2D(256, (5, 5), padding = "same",activation = "relu", name = 'conv2')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_conv2')(X)
    X = tf.keras.layers.Conv2D(256, (3, 3), padding = "same",activation = "relu", name = 'conv5')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.Flatten()(X)
    X = tf.keras.layers.Dense(4096, activation = "relu", name='fc' + str(1))(X)
    X = tf.keras.layers.Dense(4096, activation = "relu", name='fc' + str(2))(X)
    X = tf.keras.layers.Dense(classes, activation = "linear",kernel_regularizer=tf.keras.regularizers.l2(0.01), name='fc' + str(classes))(X)
       
    model = tf.keras.Model(inputs = X_input, outputs = X, name='ALEXNETHINGE')

    return model

# %%
model = AlexNetHinge()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000005), 
              loss='categorical_hinge', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "ALEXNETHINGE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv1 (Conv2D)              (None, 55, 55, 96)        34944
#
#  max_pooling2d (MaxPooling2  (None, 27, 27, 96)        0
#  D)
#
#  bn_conv1 (BatchNormalizati  (None, 27, 27, 96)        384
#  on)
#
#  conv2 (Conv2D)              (None, 27, 27, 256)       614656
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  bn_conv2 (BatchNormalizati  (None, 13, 13, 256)       1024
#  on)
#
#  conv5 (Conv2D)              (None, 13, 13, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  fc1 (Dense)                 (None, 4096)              37752832
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  fc6 (Dense)                 (None, 6)                 24582
#
# =================================================================
# Total params: 55799814 (212.86 MB)
# Trainable params: 55799110 (212.86 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %%
hin_train_loss = []
hin_train_acc = []
hin_test_loss = []
hin_test_acc = []
for i in range(20):
    print("Training Process "+str(len(hin_train_loss)))
    history = model.fit(train_gen.flow(train_X, train_Y.T, batch_size=32),steps_per_epoch=60,epochs=1)
    print("Test Result "+str(len(hin_train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    hin_train_loss.append(history.history["loss"][0])
    hin_train_acc.append(history.history["accuracy"][0])
    hin_test_loss.append(preds[0])
    hin_test_acc.append(preds[1])
plt.plot(hin_train_loss)
plt.show()
plt.plot(hin_test_loss)
plt.show()
# Out:
# Training Process 0
# 60/60 [==============================] - 42s 661ms/step - loss: 1.4311 - accuracy: 0.3786
# Test Result 0
# 20/20 [==============================] - 2s 92ms/step - loss: 3.1015 - accuracy: 0.2796
# Loss = 3.1014564037323
# Test Accuracy = 0.27962085604667664
# Training Process 1
# 60/60 [==============================] - 40s 662ms/step - loss: 1.1908 - accuracy: 0.4900
# Test Result 1
# 20/20 [==============================] - 2s 94ms/step - loss: 2.1057 - accuracy: 0.3365
# Loss = 2.105729103088379
# Test Accuracy = 0.3364928960800171
# Training Process 2
# 60/60 [==============================] - 41s 674ms/step - loss: 1.1160 - accuracy: 0.5333
# Test Result 2
# 20/20 [==============================] - 2s 97ms/step - loss: 1.2710 - accuracy: 0.4660
# Loss = 1.2709860801696777
# Test Accuracy = 0.46603477001190186
# Training Process 3
# 60/60 [==============================] - 39s 640ms/step - loss: 1.0616 - accuracy: 0.5385
# Test Result 3
# 20/20 [==============================] - 2s 99ms/step - loss: 1.0567 - accuracy: 0.5687
# Loss = 1.056749701499939
# Test Accuracy = 0.5687204003334045
# Training Process 4
# 60/60 [==============================] - 39s 648ms/step - loss: 1.0646 - accuracy: 0.5565
# Test Result 4
# 20/20 [==============================] - 2s 103ms/step - loss: 1.0577 - accuracy: 0.5687
# Loss = 1.0576754808425903
# Test Accuracy = 0.5687204003334045
# Training Process 5
# 60/60 [==============================] - 40s 665ms/step - loss: 0.9799 - accuracy: 0.5956
# Test Result 5
# 20/20 [==============================] - 2s 109ms/step - loss: 1.0366 - accuracy: 0.5829
# Loss = 1.0366393327713013
# Test Accuracy = 0.5829383730888367
# Training Process 6
# 60/60 [==============================] - 42s 692ms/step - loss: 0.9610 - accuracy: 0.6045
# Test Result 6
# 20/20 [==============================] - 2s 105ms/step - loss: 1.0550 - accuracy: 0.5829
# Loss = 1.055017352104187
# Test Accuracy = 0.5829383730888367
# Training Process 7
# 60/60 [==============================] - 44s 701ms/step - loss: 0.9331 - accuracy: 0.6146
# Test Result 7
# 20/20 [==============================] - 2s 106ms/step - loss: 1.0014 - accuracy: 0.6098
# Loss = 1.001433253288269
# Test Accuracy = 0.6097946166992188
# Training Process 8
# 60/60 [==============================] - 41s 686ms/step - loss: 0.9056 - accuracy: 0.6394
# Test Result 8
# 20/20 [==============================] - 2s 99ms/step - loss: 0.9504 - accuracy: 0.6493
# Loss = 0.9503545165061951
# Test Accuracy = 0.649289071559906
# Training Process 9
# 60/60 [==============================] - 40s 664ms/step - loss: 0.9246 - accuracy: 0.6294
# Test Result 9
# 20/20 [==============================] - 2s 105ms/step - loss: 0.9955 - accuracy: 0.6003
# Loss = 0.9954585433006287
# Test Accuracy = 0.6003159284591675
# Training Process 10
# 60/60 [==============================] - 41s 683ms/step - loss: 0.8938 - accuracy: 0.6531
# Test Result 10
# 20/20 [==============================] - 2s 106ms/step - loss: 1.0180 - accuracy: 0.6114
# Loss = 1.0179890394210815
# Test Accuracy = 0.6113743782043457
# Training Process 11
# 60/60 [==============================] - 40s 672ms/step - loss: 0.8869 - accuracy: 0.6510
# Test Result 11
# 20/20 [==============================] - 2s 102ms/step - loss: 0.9654 - accuracy: 0.6445
# Loss = 0.9654321074485779
# Test Accuracy = 0.6445497870445251
# Training Process 12
# 60/60 [==============================] - 39s 655ms/step - loss: 0.8409 - accuracy: 0.6790
# Test Result 12
# 20/20 [==============================] - 2s 103ms/step - loss: 1.0327 - accuracy: 0.6161
# Loss = 1.03269362449646
# Test Accuracy = 0.6161137223243713
# Training Process 13
# 60/60 [==============================] - 40s 672ms/step - loss: 0.8460 - accuracy: 0.6568
# Test Result 13
# 20/20 [==============================] - 2s 109ms/step - loss: 0.9136 - accuracy: 0.6667
# Loss = 0.9135952591896057
# Test Accuracy = 0.6666666865348816
# Training Process 14
# 60/60 [==============================] - 42s 699ms/step - loss: 0.8453 - accuracy: 0.6774
# Test Result 14
# 20/20 [==============================] - 2s 105ms/step - loss: 0.9437 - accuracy: 0.6524
# Loss = 0.9436818361282349
# Test Accuracy = 0.6524486541748047
# Training Process 15
# 60/60 [==============================] - 43s 710ms/step - loss: 0.8203 - accuracy: 0.6753
# Test Result 15
# 20/20 [==============================] - 2s 107ms/step - loss: 0.9048 - accuracy: 0.6714
# Loss = 0.9047862887382507
# Test Accuracy = 0.6714060306549072
# Training Process 16
# 60/60 [==============================] - 43s 712ms/step - loss: 0.8258 - accuracy: 0.6753
# Test Result 16
# 20/20 [==============================] - 2s 112ms/step - loss: 0.9855 - accuracy: 0.6367
# Loss = 0.9855158925056458
# Test Accuracy = 0.6366508603096008
# Training Process 17
# 60/60 [==============================] - 41s 676ms/step - loss: 0.8121 - accuracy: 0.6859
# Test Result 17
# 20/20 [==============================] - 2s 107ms/step - loss: 0.8935 - accuracy: 0.6872
# Loss = 0.8934984803199768
# Test Accuracy = 0.6872037649154663
# Training Process 18
# 60/60 [==============================] - 42s 692ms/step - loss: 0.8015 - accuracy: 0.6785
# Test Result 18
# 20/20 [==============================] - 2s 109ms/step - loss: 0.9485 - accuracy: 0.6730
# Loss = 0.9484846591949463
# Test Accuracy = 0.6729857921600342
# Training Process 19
# 60/60 [==============================] - 41s 680ms/step - loss: 0.7776 - accuracy: 0.7017
# Test Result 19
# 20/20 [==============================] - 2s 106ms/step - loss: 0.9617 - accuracy: 0.6509
# Loss = 0.9616502523422241
# Test Accuracy = 0.6508688926696777

# %%
for i in range(10):
    print("Training Process "+str(len(hin_train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(hin_train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    hin_train_loss.append(history.history["loss"][0])
    hin_train_acc.append(history.history["accuracy"][0])
    hin_test_loss.append(preds[0])
    hin_test_acc.append(preds[1])
plt.plot(hin_train_loss)
plt.show()
plt.plot(hin_test_loss)
plt.show()
# Out:
# Training Process 20
# 60/60 [==============================] - 40s 655ms/step - loss: 0.7184 - accuracy: 0.7297
# Test Result 20
# 20/20 [==============================] - 2s 121ms/step - loss: 0.8418 - accuracy: 0.6919
# Loss = 0.8418165445327759
# Test Accuracy = 0.6919431090354919
# Training Process 21
# 60/60 [==============================] - 41s 688ms/step - loss: 0.5940 - accuracy: 0.8094
# Test Result 21
# 20/20 [==============================] - 2s 113ms/step - loss: 0.8357 - accuracy: 0.6983
# Loss = 0.8357200622558594
# Test Accuracy = 0.6982622146606445
# Training Process 22
# 60/60 [==============================] - 39s 650ms/step - loss: 0.5035 - accuracy: 0.8490
# Test Result 22
# 20/20 [==============================] - 2s 117ms/step - loss: 0.7617 - accuracy: 0.7393
# Loss = 0.7617331147193909
# Test Accuracy = 0.7393364906311035
# Training Process 23
# 60/60 [==============================] - 39s 649ms/step - loss: 0.4290 - accuracy: 0.8907
# Test Result 23
# 20/20 [==============================] - 2s 113ms/step - loss: 0.7508 - accuracy: 0.7235
# Loss = 0.7508305311203003
# Test Accuracy = 0.7235386967658997
# Training Process 24
# 60/60 [==============================] - 40s 661ms/step - loss: 0.3643 - accuracy: 0.9182
# Test Result 24
# 20/20 [==============================] - 2s 110ms/step - loss: 0.7474 - accuracy: 0.7299
# Loss = 0.7473593950271606
# Test Accuracy = 0.7298578023910522
# Training Process 25
# 60/60 [==============================] - 38s 636ms/step - loss: 0.3318 - accuracy: 0.9351
# Test Result 25
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7148 - accuracy: 0.7551
# Loss = 0.714770495891571
# Test Accuracy = 0.7551342844963074
# Training Process 26
# 60/60 [==============================] - 39s 656ms/step - loss: 0.3004 - accuracy: 0.9483
# Test Result 26
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7852 - accuracy: 0.6998
# Loss = 0.7851676940917969
# Test Accuracy = 0.6998420357704163
# Training Process 27
# 60/60 [==============================] - 39s 653ms/step - loss: 0.2715 - accuracy: 0.9599
# Test Result 27
# 20/20 [==============================] - 2s 112ms/step - loss: 0.7287 - accuracy: 0.7615
# Loss = 0.7286801934242249
# Test Accuracy = 0.76145339012146
# Training Process 28
# 60/60 [==============================] - 39s 654ms/step - loss: 0.2472 - accuracy: 0.9720
# Test Result 28
# 20/20 [==============================] - 2s 112ms/step - loss: 0.7384 - accuracy: 0.7314
# Loss = 0.7383784651756287
# Test Accuracy = 0.731437623500824
# Training Process 29
# 60/60 [==============================] - 40s 661ms/step - loss: 0.2385 - accuracy: 0.9768
# Test Result 29
# 20/20 [==============================] - 2s 111ms/step - loss: 0.7266 - accuracy: 0.7441
# Loss = 0.7266495227813721
# Test Accuracy = 0.7440758347511292

# %%
for i in range(10):
    print("Training Process "+str(len(hin_train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(hin_train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    hin_train_loss.append(history.history["loss"][0])
    hin_train_acc.append(history.history["accuracy"][0])
    hin_test_loss.append(preds[0])
    hin_test_acc.append(preds[1])
plt.plot(hin_train_loss)
plt.show()
plt.plot(hin_test_loss)
plt.show()
# Out:
# Training Process 30
# 60/60 [==============================] - 38s 634ms/step - loss: 0.2072 - accuracy: 0.9842
# Test Result 30
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7191 - accuracy: 0.7457
# Loss = 0.7191305756568909
# Test Accuracy = 0.7456555962562561
# Training Process 31
# 60/60 [==============================] - 39s 645ms/step - loss: 0.1959 - accuracy: 0.9879
# Test Result 31
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7418 - accuracy: 0.7330
# Loss = 0.7418062090873718
# Test Accuracy = 0.7330173850059509
# Training Process 32
# 60/60 [==============================] - 40s 666ms/step - loss: 0.1778 - accuracy: 0.9873
# Test Result 32
# 20/20 [==============================] - 2s 115ms/step - loss: 0.7319 - accuracy: 0.7409
# Loss = 0.7319127917289734
# Test Accuracy = 0.7409162521362305
# Training Process 33
# 60/60 [==============================] - 39s 658ms/step - loss: 0.1671 - accuracy: 0.9894
# Test Result 33
# 20/20 [==============================] - 2s 112ms/step - loss: 0.7153 - accuracy: 0.7409
# Loss = 0.7153403759002686
# Test Accuracy = 0.7409162521362305
# Training Process 34
# 60/60 [==============================] - 40s 666ms/step - loss: 0.1628 - accuracy: 0.9937
# Test Result 34
# 20/20 [==============================] - 2s 112ms/step - loss: 0.7353 - accuracy: 0.7362
# Loss = 0.7352639436721802
# Test Accuracy = 0.7361769080162048
# Training Process 35
# 60/60 [==============================] - 39s 656ms/step - loss: 0.1652 - accuracy: 0.9952
# Test Result 35
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7653 - accuracy: 0.7220
# Loss = 0.7652928233146667
# Test Accuracy = 0.7219589352607727
# Training Process 36
# 60/60 [==============================] - 38s 641ms/step - loss: 0.1609 - accuracy: 0.9958
# Test Result 36
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7515 - accuracy: 0.7362
# Loss = 0.7515202164649963
# Test Accuracy = 0.7361769080162048
# Training Process 37
# 60/60 [==============================] - 39s 654ms/step - loss: 0.1517 - accuracy: 0.9958
# Test Result 37
# 20/20 [==============================] - 2s 117ms/step - loss: 0.7274 - accuracy: 0.7299
# Loss = 0.727388858795166
# Test Accuracy = 0.7298578023910522
# Training Process 38
# 60/60 [==============================] - 39s 650ms/step - loss: 0.1394 - accuracy: 0.9963
# Test Result 38
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7320 - accuracy: 0.7409
# Loss = 0.7320152521133423
# Test Accuracy = 0.7409162521362305
# Training Process 39
# 60/60 [==============================] - 39s 642ms/step - loss: 0.1421 - accuracy: 0.9974
# Test Result 39
# 20/20 [==============================] - 2s 107ms/step - loss: 0.7343 - accuracy: 0.7378
# Loss = 0.7343251705169678
# Test Accuracy = 0.7377567291259766

# %%
for i in range(10):
    print("Training Process "+str(len(hin_train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(hin_train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    hin_train_loss.append(history.history["loss"][0])
    hin_train_acc.append(history.history["accuracy"][0])
    hin_test_loss.append(preds[0])
    hin_test_acc.append(preds[1])
plt.plot(hin_train_loss)
plt.show()
plt.plot(hin_test_loss)
plt.show()
# Out:
# Training Process 40
# 60/60 [==============================] - 39s 642ms/step - loss: 0.1374 - accuracy: 0.9974
# Test Result 40
# 20/20 [==============================] - 2s 107ms/step - loss: 0.7497 - accuracy: 0.7457
# Loss = 0.7496912479400635
# Test Accuracy = 0.7456555962562561
# Training Process 41
# 60/60 [==============================] - 38s 638ms/step - loss: 0.1405 - accuracy: 0.9974
# Test Result 41
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7199 - accuracy: 0.7536
# Loss = 0.7198910117149353
# Test Accuracy = 0.7535545229911804
# Training Process 42
# 60/60 [==============================] - 39s 655ms/step - loss: 0.1398 - accuracy: 0.9963
# Test Result 42
# 20/20 [==============================] - 2s 118ms/step - loss: 0.7282 - accuracy: 0.7457
# Loss = 0.7281697988510132
# Test Accuracy = 0.7456555962562561
# Training Process 43
# 60/60 [==============================] - 39s 646ms/step - loss: 0.1365 - accuracy: 0.9974
# Test Result 43
# 20/20 [==============================] - 2s 110ms/step - loss: 0.7311 - accuracy: 0.7457
# Loss = 0.7311273813247681
# Test Accuracy = 0.7456555962562561
# Training Process 44
# 60/60 [==============================] - 40s 668ms/step - loss: 0.1319 - accuracy: 0.9979
# Test Result 44
# 20/20 [==============================] - 2s 121ms/step - loss: 0.7189 - accuracy: 0.7425
# Loss = 0.7188754677772522
# Test Accuracy = 0.7424960732460022
# Training Process 45
# 60/60 [==============================] - 39s 656ms/step - loss: 0.1472 - accuracy: 0.9952
# Test Result 45
# 20/20 [==============================] - 2s 111ms/step - loss: 0.7169 - accuracy: 0.7520
# Loss = 0.7168784737586975
# Test Accuracy = 0.7519747018814087
# Training Process 46
# 60/60 [==============================] - 39s 650ms/step - loss: 0.1269 - accuracy: 0.9989
# Test Result 46
# 20/20 [==============================] - 2s 116ms/step - loss: 0.7590 - accuracy: 0.7346
# Loss = 0.7589743137359619
# Test Accuracy = 0.7345971465110779
# Training Process 47
# 60/60 [==============================] - 40s 661ms/step - loss: 0.1400 - accuracy: 0.9958
# Test Result 47
# 20/20 [==============================] - 2s 118ms/step - loss: 0.7205 - accuracy: 0.7551
# Loss = 0.7205305695533752
# Test Accuracy = 0.7551342844963074
# Training Process 48
# 60/60 [==============================] - 39s 644ms/step - loss: 0.1354 - accuracy: 0.9984
# Test Result 48
# 20/20 [==============================] - 2s 107ms/step - loss: 0.7476 - accuracy: 0.7393
# Loss = 0.7475566864013672
# Test Accuracy = 0.7393364906311035
# Training Process 49
# 60/60 [==============================] - 38s 629ms/step - loss: 0.1257 - accuracy: 0.9984
# Test Result 49
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7614 - accuracy: 0.7283
# Loss = 0.7614366412162781
# Test Accuracy = 0.7282780408859253

# %%
for i in range(10):
    print("Training Process "+str(len(hin_train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(hin_train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    hin_train_loss.append(history.history["loss"][0])
    hin_train_acc.append(history.history["accuracy"][0])
    hin_test_loss.append(preds[0])
    hin_test_acc.append(preds[1])
plt.plot(hin_train_loss)
plt.show()
plt.plot(hin_test_loss)
plt.show()
# Out:
# Training Process 50
# 60/60 [==============================] - 37s 616ms/step - loss: 0.1314 - accuracy: 0.9979
# Test Result 50
# 20/20 [==============================] - 2s 104ms/step - loss: 0.7416 - accuracy: 0.7362
# Loss = 0.7416273951530457
# Test Accuracy = 0.7361769080162048
# Training Process 51
# 60/60 [==============================] - 37s 611ms/step - loss: 0.1234 - accuracy: 1.0000
# Test Result 51
# 20/20 [==============================] - 2s 106ms/step - loss: 0.7181 - accuracy: 0.7678
# Loss = 0.718079686164856
# Test Accuracy = 0.7677724957466125
# Training Process 52
# 60/60 [==============================] - 36s 600ms/step - loss: 0.1335 - accuracy: 0.9989
# Test Result 52
# 20/20 [==============================] - 2s 106ms/step - loss: 0.7322 - accuracy: 0.7378
# Loss = 0.732201099395752
# Test Accuracy = 0.7377567291259766
# Training Process 53
# 60/60 [==============================] - 36s 600ms/step - loss: 0.1194 - accuracy: 0.9995
# Test Result 53
# 20/20 [==============================] - 2s 107ms/step - loss: 0.7346 - accuracy: 0.7362
# Loss = 0.7346227765083313
# Test Accuracy = 0.7361769080162048
# Training Process 54
# 60/60 [==============================] - 37s 609ms/step - loss: 0.1214 - accuracy: 1.0000
# Test Result 54
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7393 - accuracy: 0.7520
# Loss = 0.7392881512641907
# Test Accuracy = 0.7519747018814087
# Training Process 55
# 60/60 [==============================] - 38s 640ms/step - loss: 0.1226 - accuracy: 1.0000
# Test Result 55
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7314 - accuracy: 0.7425
# Loss = 0.7314028143882751
# Test Accuracy = 0.7424960732460022
# Training Process 56
# 60/60 [==============================] - 38s 637ms/step - loss: 0.1271 - accuracy: 0.9984
# Test Result 56
# 20/20 [==============================] - 2s 112ms/step - loss: 0.7323 - accuracy: 0.7567
# Loss = 0.7322608232498169
# Test Accuracy = 0.7567140460014343
# Training Process 57
# 60/60 [==============================] - 38s 637ms/step - loss: 0.1190 - accuracy: 0.9995
# Test Result 57
# 20/20 [==============================] - 2s 113ms/step - loss: 0.7334 - accuracy: 0.7551
# Loss = 0.7334072589874268
# Test Accuracy = 0.7551342844963074
# Training Process 58
# 60/60 [==============================] - 38s 638ms/step - loss: 0.1168 - accuracy: 1.0000
# Test Result 58
# 20/20 [==============================] - 2s 121ms/step - loss: 0.7320 - accuracy: 0.7488
# Loss = 0.7320465445518494
# Test Accuracy = 0.7488151788711548
# Training Process 59
# 60/60 [==============================] - 39s 645ms/step - loss: 0.1203 - accuracy: 0.9989
# Test Result 59
# 20/20 [==============================] - 2s 118ms/step - loss: 0.7530 - accuracy: 0.7567
# Loss = 0.7530220746994019
# Test Accuracy = 0.7567140460014343

# %%
error = [0,0,0,0,0,0]
mislabel = np.zeros((6,6))
prediction = model.predict(test_X_re)
for i in range(test_X_re.shape[0]):
    if(test_Y_re[np.argmax(prediction,axis=1)[i],i] == 0):
        if(i<101):
            error[0] = error[0]+1
            mislabel[0][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<226):
            error[1] = error[1]+1
            mislabel[1][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<329):
            error[2] = error[2]+1
            mislabel[2][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<478):
            error[3] = error[3]+1
            mislabel[3][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<599):
            error[4] = error[4]+1
            mislabel[4][np.argmax(prediction,axis=1)[i]] += 1
        else:
            error[5] = error[5]+1
            mislabel[5][np.argmax(prediction,axis=1)[i]] += 1
# Out:
# 20/20 [==============================] - 3s 106ms/step

# %%
total = np.array([101,125,103,149,121,34])
error = np.array(error)
error = np.divide(error,total)
print("% of mislabeled cardboard: "+str(error[0]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[0]))
print("% of mislabeled glass: "+str(error[1]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[1]))
print("% of mislabeled metal: "+str(error[2]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[2]))
print("% of mislabeled paper: "+str(error[3]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[3]))
print("% of mislabeled plastic: "+str(error[4]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[4]))
print("% of mislabeled trash: "+str(error[5]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[5]))
# Out:
# % of mislabeled cardboard: 0.13861386138613863
# Mostly mislabeled as: 4
# % of mislabeled glass: 0.168
# Mostly mislabeled as: 4
# % of mislabeled metal: 0.33980582524271846
# Mostly mislabeled as: 1
# % of mislabeled paper: 0.18791946308724833
# Mostly mislabeled as: 2
# % of mislabeled plastic: 0.36363636363636365
# Mostly mislabeled as: 1
# % of mislabeled trash: 0.35294117647058826
# Mostly mislabeled as: 4

# %%
f = open('train_loss\hin_train_loss_aug_p.txt', 'w')
for i in hin_train_loss:
    f.write(str(i))
    f.write("\n")
f.close()

# %%
f = open('train_acc\hin_train_acc_aug_p.txt', 'w')
for i in hin_train_acc:
    f.write(str(i))
    f.write("\n")
f.close()

# %%
f = open('test_acc\hin_test_acc_aug_p.txt', 'w')
for i in hin_test_acc:
    f.write(str(i))
    f.write("\n")
f.close()
