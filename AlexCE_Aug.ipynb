# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# C:\Users\Duy.TC214885\AppData\Local\miniconda3\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.12.2 when it was built against 1.12.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
cardboard = []
for i in range(1,404):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/cardboard/cardboard"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    cardboard.append(X)
cardboard = np.array(cardboard)
cardboard = np.take(cardboard,np.random.permutation(cardboard.shape[0]),axis=0)
print(cardboard.shape)
# Out:
# (403, 227, 227, 3)

# %%
glass = []
for i in range(1,502):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/glass/glass"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    glass.append(X)
glass = np.array(glass)
glass = np.take(glass,np.random.permutation(glass.shape[0]),axis=0)
print(glass.shape)
# Out:
# (501, 227, 227, 3)

# %%
metal = []
for i in range(1,411):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/metal/metal"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    metal.append(X)
metal = np.array(metal)
metal = np.take(metal,np.random.permutation(metal.shape[0]),axis=0)
print(metal.shape)
# Out:
# (410, 227, 227, 3)

# %%
paper = []
for i in range(1,595):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/paper/paper"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    paper.append(X)
paper = np.array(paper)
paper = np.take(paper,np.random.permutation(paper.shape[0]),axis=0)
print(paper.shape)
# Out:
# (594, 227, 227, 3)

# %%
plastic = []
for i in range(1,483):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/plastic/plastic"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    plastic.append(X)
plastic = np.array(plastic)
plastic = np.take(plastic,np.random.permutation(plastic.shape[0]),axis=0)
print(plastic.shape)
# Out:
# (482, 227, 227, 3)

# %%
trash = []
for i in range(1,138):
    temp = tf.keras.preprocessing.image.load_img(
        path = "dataset-resized/trash/trash"+str(i)+".jpg",
        grayscale=False, color_mode='rgb',target_size=(227,227))
    X = np.array(temp)
    trash.append(X)
trash = np.array(trash)
trash = np.take(trash,np.random.permutation(trash.shape[0]),axis=0)
print(trash.shape)
# Out:
# (137, 227, 227, 3)

# %%
train_X = np.vstack((cardboard[:302,:,:,:],glass[:376,:,:,:],metal[:307,:,:,:],
                    paper[:445,:,:,:],plastic[:361,:,:,:],trash[:103,:,:,:]))
test_X = np.vstack((cardboard[302:,:,:,:],glass[376:,:,:,:],metal[307:,:,:,:],
                   paper[445:,:,:,:],plastic[361:,:,:,:],trash[103:,:,:,:]))
train_Y = np.zeros((6,train_X.shape[0]))
test_Y = np.zeros((6,test_X.shape[0]))
for i in range(train_X.shape[0]):
    if(i<302):
        train_Y[0][i] = 1
    elif(i<678):
        train_Y[1][i] = 1
    elif(i<985):
        train_Y[2][i] = 1
    elif(i<1430):
        train_Y[3][i] = 1
    elif(i<1791):
        train_Y[4][i] = 1
    else:
        train_Y[5][i] = 1
for i in range(test_X.shape[0]):
    if(i<101):
        test_Y[0][i] = 1
    elif(i<226):
        test_Y[1][i] = 1
    elif(i<329):
        test_Y[2][i] = 1
    elif(i<478):
        test_Y[3][i] = 1
    elif(i<599):
        test_Y[4][i] = 1
    else:
        test_Y[5][i] = 1

# %%
test_X_re = test_X
test_Y_re = test_Y

# %%
np.random.seed(1013)
train_perm = np.random.permutation(train_X.shape[0])
train_X = np.take(train_X,train_perm,axis=0)
print(train_X.shape)
train_Y = np.take(train_Y,train_perm,axis=1)
print(train_Y.shape)
np.random.seed(901)
test_perm = np.random.permutation(test_X.shape[0])
test_X = np.take(test_X,test_perm,axis=0)
print(test_X.shape)
test_Y = np.take(test_Y,test_perm,axis=1)
print(test_Y.shape)
# Out:
# (1894, 227, 227, 3)
# (6, 1894)
# (633, 227, 227, 3)
# (6, 633)

# %%
train_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    width_shift_range=0.1,height_shift_range=0.1, rotation_range=45, zoom_range=0.1,
    horizontal_flip=True,vertical_flip=True)
train_gen.fit(train_X)

# %%
def AlexNetCE(input_shape = (227, 227, 3), classes = 6):
    X_input = tf.keras.Input(input_shape)
    X = X_input
    X = tf.keras.layers.Conv2D(96, (11, 11), strides = (4, 4), activation = "relu", name = 'conv1')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = tf.keras.layers.Conv2D(256, (5, 5), padding = "same",activation = "relu", name = 'conv2')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_conv2')(X)
    X = tf.keras.layers.Conv2D(256, (3, 3), padding = "same",activation = "relu", name = 'conv5')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.Flatten()(X)
    X = tf.keras.layers.Dense(4096, activation = "relu", name='fc' + str(1))(X)
    X = tf.keras.layers.Dense(4096, activation = "relu", name='fc' + str(2))(X)
    X = tf.keras.layers.Dense(classes, activation='softmax', name='fc' + str(classes))(X)

    model = tf.keras.Model(inputs = X_input, outputs = X, name='ALEXNETCE')

    return model

# %%
model = AlexNetCE()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000005), 
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "ALEXNETCE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  conv1 (Conv2D)              (None, 55, 55, 96)        34944
#
#  max_pooling2d (MaxPooling2  (None, 27, 27, 96)        0
#  D)
#
#  bn_conv1 (BatchNormalizati  (None, 27, 27, 96)        384
#  on)
#
#  conv2 (Conv2D)              (None, 27, 27, 256)       614656
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  bn_conv2 (BatchNormalizati  (None, 13, 13, 256)       1024
#  on)
#
#  conv5 (Conv2D)              (None, 13, 13, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  fc1 (Dense)                 (None, 4096)              37752832
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  fc6 (Dense)                 (None, 6)                 24582
#
# =================================================================
# Total params: 55799814 (212.86 MB)
# Trainable params: 55799110 (212.86 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %%
train_loss = []
train_acc = []
test_loss = []
test_acc = []
for i in range(20):
    print("Training Process "+str(len(train_loss)))
    history = model.fit(train_gen.flow(train_X, train_Y.T, batch_size=32),steps_per_epoch=60,epochs=1)
    print("Test Result "+str(len(train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    train_loss.append(history.history["loss"][0])
    train_acc.append(history.history["accuracy"][0])
    test_loss.append(preds[0])
    test_acc.append(preds[1])
plt.plot(train_loss)
plt.show()
plt.plot(test_loss)
plt.show()
# Out:
# Training Process 0
# 60/60 [==============================] - 41s 649ms/step - loss: 1.5581 - accuracy: 0.4013
# Test Result 0
# 20/20 [==============================] - 2s 91ms/step - loss: 4.5361 - accuracy: 0.2385
# Loss = 4.536067962646484
# Test Accuracy = 0.23854660987854004
# Training Process 1
# 60/60 [==============================] - 38s 635ms/step - loss: 1.2918 - accuracy: 0.4963
# Test Result 1
# 20/20 [==============================] - 2s 92ms/step - loss: 2.3724 - accuracy: 0.3254
# Loss = 2.3723719120025635
# Test Accuracy = 0.32543444633483887
# Training Process 2
# 60/60 [==============================] - 44s 738ms/step - loss: 1.2303 - accuracy: 0.5327
# Test Result 2
# 20/20 [==============================] - 3s 130ms/step - loss: 1.6013 - accuracy: 0.4376
# Loss = 1.6012871265411377
# Test Accuracy = 0.43759873509407043
# Training Process 3
# 60/60 [==============================] - 48s 796ms/step - loss: 1.1390 - accuracy: 0.5660
# Test Result 3
# 20/20 [==============================] - 2s 114ms/step - loss: 1.3583 - accuracy: 0.4929
# Loss = 1.358327865600586
# Test Accuracy = 0.49289098381996155
# Training Process 4
# 60/60 [==============================] - 47s 774ms/step - loss: 1.1141 - accuracy: 0.5982
# Test Result 4
# 20/20 [==============================] - 2s 106ms/step - loss: 1.1981 - accuracy: 0.5498
# Loss = 1.1980584859848022
# Test Accuracy = 0.549763023853302
# Training Process 5
# 60/60 [==============================] - 39s 648ms/step - loss: 1.0754 - accuracy: 0.5966
# Test Result 5
# 20/20 [==============================] - 2s 99ms/step - loss: 1.0969 - accuracy: 0.6019
# Loss = 1.0969321727752686
# Test Accuracy = 0.6018957495689392
# Training Process 6
# 60/60 [==============================] - 41s 677ms/step - loss: 1.0216 - accuracy: 0.6162
# Test Result 6
# 20/20 [==============================] - 2s 104ms/step - loss: 1.0724 - accuracy: 0.6145
# Loss = 1.0724315643310547
# Test Accuracy = 0.6145339608192444
# Training Process 7
# 60/60 [==============================] - 42s 693ms/step - loss: 1.0213 - accuracy: 0.6288
# Test Result 7
# 20/20 [==============================] - 2s 106ms/step - loss: 1.0679 - accuracy: 0.6335
# Loss = 1.067856788635254
# Test Accuracy = 0.6334913372993469
# Training Process 8
# 60/60 [==============================] - 40s 655ms/step - loss: 0.9711 - accuracy: 0.6457
# Test Result 8
# 20/20 [==============================] - 2s 103ms/step - loss: 1.1458 - accuracy: 0.6082
# Loss = 1.1458022594451904
# Test Accuracy = 0.6082148551940918
# Training Process 9
# 60/60 [==============================] - 40s 657ms/step - loss: 0.9542 - accuracy: 0.6505
# Test Result 9
# 20/20 [==============================] - 2s 104ms/step - loss: 0.9761 - accuracy: 0.6319
# Loss = 0.9760698080062866
# Test Accuracy = 0.6319115161895752
# Training Process 10
# 60/60 [==============================] - 40s 663ms/step - loss: 0.9393 - accuracy: 0.6568
# Test Result 10
# 20/20 [==============================] - 2s 101ms/step - loss: 1.0393 - accuracy: 0.6540
# Loss = 1.0393383502960205
# Test Accuracy = 0.6540284156799316
# Training Process 11
# 60/60 [==============================] - 42s 697ms/step - loss: 0.8927 - accuracy: 0.6721
# Test Result 11
# 20/20 [==============================] - 2s 104ms/step - loss: 1.0386 - accuracy: 0.6382
# Loss = 1.0385708808898926
# Test Accuracy = 0.6382306218147278
# Training Process 12
# 60/60 [==============================] - 40s 663ms/step - loss: 0.8969 - accuracy: 0.6864
# Test Result 12
# 20/20 [==============================] - 2s 103ms/step - loss: 0.9935 - accuracy: 0.6840
# Loss = 0.9934520721435547
# Test Accuracy = 0.6840442419052124
# Training Process 13
# 60/60 [==============================] - 39s 655ms/step - loss: 0.8872 - accuracy: 0.6774
# Test Result 13
# 20/20 [==============================] - 2s 101ms/step - loss: 0.9401 - accuracy: 0.6556
# Loss = 0.9400613307952881
# Test Accuracy = 0.6556082367897034
# Training Process 14
# 60/60 [==============================] - 42s 698ms/step - loss: 0.8721 - accuracy: 0.6800
# Test Result 14
# 20/20 [==============================] - 2s 106ms/step - loss: 0.9722 - accuracy: 0.6730
# Loss = 0.972220242023468
# Test Accuracy = 0.6729857921600342
# Training Process 15
# 60/60 [==============================] - 41s 676ms/step - loss: 0.8232 - accuracy: 0.6969
# Test Result 15
# 20/20 [==============================] - 2s 104ms/step - loss: 0.9538 - accuracy: 0.6698
# Loss = 0.9538142085075378
# Test Accuracy = 0.6698262095451355
# Training Process 16
# 60/60 [==============================] - 41s 679ms/step - loss: 0.8418 - accuracy: 0.6906
# Test Result 16
# 20/20 [==============================] - 2s 109ms/step - loss: 0.8702 - accuracy: 0.6904
# Loss = 0.8701616525650024
# Test Accuracy = 0.690363347530365
# Training Process 17
# 60/60 [==============================] - 45s 733ms/step - loss: 0.8000 - accuracy: 0.7107
# Test Result 17
# 20/20 [==============================] - 2s 111ms/step - loss: 0.9116 - accuracy: 0.7062
# Loss = 0.9116095304489136
# Test Accuracy = 0.7061611413955688
# Training Process 18
# 60/60 [==============================] - 42s 693ms/step - loss: 0.7953 - accuracy: 0.7112
# Test Result 18
# 20/20 [==============================] - 2s 106ms/step - loss: 0.9646 - accuracy: 0.6840
# Loss = 0.9646191596984863
# Test Accuracy = 0.6840442419052124
# Training Process 19
# 60/60 [==============================] - 43s 717ms/step - loss: 0.7662 - accuracy: 0.7233
# Test Result 19
# 20/20 [==============================] - 2s 107ms/step - loss: 0.9068 - accuracy: 0.7172
# Loss = 0.9067821502685547
# Test Accuracy = 0.7172195911407471

# %%
for i in range(10):
    print("Training Process "+str(len(train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    train_loss.append(history.history["loss"][0])
    train_acc.append(history.history["accuracy"][0])
    test_loss.append(preds[0])
    test_acc.append(preds[1])
plt.plot(train_loss)
plt.show()
plt.plot(test_loss)
plt.show()
# Out:
# Training Process 20
# 60/60 [==============================] - 38s 623ms/step - loss: 0.7121 - accuracy: 0.7439
# Test Result 20
# 20/20 [==============================] - 2s 103ms/step - loss: 0.7743 - accuracy: 0.7251
# Loss = 0.7742536067962646
# Test Accuracy = 0.7251184582710266
# Training Process 21
# 60/60 [==============================] - 37s 620ms/step - loss: 0.5777 - accuracy: 0.8052
# Test Result 21
# 20/20 [==============================] - 2s 107ms/step - loss: 0.7176 - accuracy: 0.7457
# Loss = 0.7175713181495667
# Test Accuracy = 0.7456555962562561
# Training Process 22
# 60/60 [==============================] - 37s 623ms/step - loss: 0.4974 - accuracy: 0.8448
# Test Result 22
# 20/20 [==============================] - 2s 111ms/step - loss: 0.6971 - accuracy: 0.7583
# Loss = 0.6971444487571716
# Test Accuracy = 0.758293867111206
# Training Process 23
# 60/60 [==============================] - 38s 635ms/step - loss: 0.4337 - accuracy: 0.8728
# Test Result 23
# 20/20 [==============================] - 2s 114ms/step - loss: 0.7095 - accuracy: 0.7678
# Loss = 0.7095224857330322
# Test Accuracy = 0.7677724957466125
# Training Process 24
# 60/60 [==============================] - 37s 623ms/step - loss: 0.3673 - accuracy: 0.9081
# Test Result 24
# 20/20 [==============================] - 2s 108ms/step - loss: 0.6592 - accuracy: 0.7757
# Loss = 0.659233033657074
# Test Accuracy = 0.7756714224815369
# Training Process 25
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3330 - accuracy: 0.9229
# Test Result 25
# 20/20 [==============================] - 2s 104ms/step - loss: 0.6757 - accuracy: 0.7583
# Loss = 0.6757316589355469
# Test Accuracy = 0.758293867111206
# Training Process 26
# 60/60 [==============================] - 37s 616ms/step - loss: 0.2975 - accuracy: 0.9356
# Test Result 26
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6958 - accuracy: 0.7678
# Loss = 0.6958009004592896
# Test Accuracy = 0.7677724957466125
# Training Process 27
# 60/60 [==============================] - 37s 614ms/step - loss: 0.2707 - accuracy: 0.9403
# Test Result 27
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6913 - accuracy: 0.7615
# Loss = 0.6913173198699951
# Test Accuracy = 0.76145339012146
# Training Process 28
# 60/60 [==============================] - 37s 620ms/step - loss: 0.2488 - accuracy: 0.9456
# Test Result 28
# 20/20 [==============================] - 2s 105ms/step - loss: 0.6703 - accuracy: 0.7757
# Loss = 0.6702503561973572
# Test Accuracy = 0.7756714224815369
# Training Process 29
# 60/60 [==============================] - 38s 629ms/step - loss: 0.2163 - accuracy: 0.9620
# Test Result 29
# 20/20 [==============================] - 2s 106ms/step - loss: 0.6525 - accuracy: 0.7709
# Loss = 0.6524984240531921
# Test Accuracy = 0.7709320783615112

# %%
for i in range(10):
    print("Training Process "+str(len(train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    train_loss.append(history.history["loss"][0])
    train_acc.append(history.history["accuracy"][0])
    test_loss.append(preds[0])
    test_acc.append(preds[1])
plt.plot(train_loss)
plt.show()
plt.plot(test_loss)
plt.show()
# Out:
# Training Process 30
# 60/60 [==============================] - 38s 631ms/step - loss: 0.2027 - accuracy: 0.9646
# Test Result 30
# 20/20 [==============================] - 2s 113ms/step - loss: 0.6394 - accuracy: 0.7820
# Loss = 0.6393864750862122
# Test Accuracy = 0.7819905281066895
# Training Process 31
# 60/60 [==============================] - 38s 633ms/step - loss: 0.1712 - accuracy: 0.9773
# Test Result 31
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6541 - accuracy: 0.7852
# Loss = 0.6541369557380676
# Test Accuracy = 0.7851500511169434
# Training Process 32
# 60/60 [==============================] - 38s 634ms/step - loss: 0.1511 - accuracy: 0.9810
# Test Result 32
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6519 - accuracy: 0.7899
# Loss = 0.651862382888794
# Test Accuracy = 0.789889395236969
# Training Process 33
# 60/60 [==============================] - 38s 628ms/step - loss: 0.1394 - accuracy: 0.9826
# Test Result 33
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6542 - accuracy: 0.7883
# Loss = 0.654193103313446
# Test Accuracy = 0.788309633731842
# Training Process 34
# 60/60 [==============================] - 38s 638ms/step - loss: 0.1430 - accuracy: 0.9778
# Test Result 34
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7033 - accuracy: 0.7583
# Loss = 0.7032843828201294
# Test Accuracy = 0.758293867111206
# Training Process 35
# 60/60 [==============================] - 37s 619ms/step - loss: 0.1225 - accuracy: 0.9820
# Test Result 35
# 20/20 [==============================] - 2s 103ms/step - loss: 0.6638 - accuracy: 0.7804
# Loss = 0.663823127746582
# Test Accuracy = 0.7804107666015625
# Training Process 36
# 60/60 [==============================] - 38s 641ms/step - loss: 0.1114 - accuracy: 0.9863
# Test Result 36
# 20/20 [==============================] - 2s 117ms/step - loss: 0.6716 - accuracy: 0.7741
# Loss = 0.6715787649154663
# Test Accuracy = 0.7740916013717651
# Training Process 37
# 60/60 [==============================] - 37s 624ms/step - loss: 0.1022 - accuracy: 0.9900
# Test Result 37
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6786 - accuracy: 0.7773
# Loss = 0.678594172000885
# Test Accuracy = 0.7772511839866638
# Training Process 38
# 60/60 [==============================] - 37s 613ms/step - loss: 0.0904 - accuracy: 0.9900
# Test Result 38
# 20/20 [==============================] - 2s 106ms/step - loss: 0.6916 - accuracy: 0.7694
# Loss = 0.6916146874427795
# Test Accuracy = 0.7693523168563843
# Training Process 39
# 60/60 [==============================] - 36s 608ms/step - loss: 0.0782 - accuracy: 0.9931
# Test Result 39
# 20/20 [==============================] - 2s 115ms/step - loss: 0.6632 - accuracy: 0.7820
# Loss = 0.6632421612739563
# Test Accuracy = 0.7819905281066895

# %%
for i in range(10):
    print("Training Process "+str(len(train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    train_loss.append(history.history["loss"][0])
    train_acc.append(history.history["accuracy"][0])
    test_loss.append(preds[0])
    test_acc.append(preds[1])
plt.plot(train_loss)
plt.show()
plt.plot(test_loss)
plt.show()
# Out:
# Training Process 40
# 60/60 [==============================] - 38s 635ms/step - loss: 0.0768 - accuracy: 0.9937
# Test Result 40
# 20/20 [==============================] - 2s 110ms/step - loss: 0.6563 - accuracy: 0.7867
# Loss = 0.6562631130218506
# Test Accuracy = 0.7867298722267151
# Training Process 41
# 60/60 [==============================] - 37s 619ms/step - loss: 0.0697 - accuracy: 0.9958
# Test Result 41
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6716 - accuracy: 0.7820
# Loss = 0.6716306805610657
# Test Accuracy = 0.7819905281066895
# Training Process 42
# 60/60 [==============================] - 37s 624ms/step - loss: 0.0643 - accuracy: 0.9947
# Test Result 42
# 20/20 [==============================] - 2s 110ms/step - loss: 0.6641 - accuracy: 0.7820
# Loss = 0.6641375422477722
# Test Accuracy = 0.7819905281066895
# Training Process 43
# 60/60 [==============================] - 38s 627ms/step - loss: 0.0581 - accuracy: 0.9974
# Test Result 43
# 20/20 [==============================] - 2s 111ms/step - loss: 0.6606 - accuracy: 0.7899
# Loss = 0.6605934500694275
# Test Accuracy = 0.789889395236969
# Training Process 44
# 60/60 [==============================] - 38s 635ms/step - loss: 0.0654 - accuracy: 0.9942
# Test Result 44
# 20/20 [==============================] - 2s 112ms/step - loss: 0.6600 - accuracy: 0.7883
# Loss = 0.6599643230438232
# Test Accuracy = 0.788309633731842
# Training Process 45
# 60/60 [==============================] - 39s 643ms/step - loss: 0.0508 - accuracy: 0.9963
# Test Result 45
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6621 - accuracy: 0.7930
# Loss = 0.662056565284729
# Test Accuracy = 0.7930489778518677
# Training Process 46
# 60/60 [==============================] - 38s 629ms/step - loss: 0.0456 - accuracy: 0.9984
# Test Result 46
# 20/20 [==============================] - 2s 110ms/step - loss: 0.6754 - accuracy: 0.7852
# Loss = 0.6753544211387634
# Test Accuracy = 0.7851500511169434
# Training Process 47
# 60/60 [==============================] - 37s 620ms/step - loss: 0.0501 - accuracy: 0.9937
# Test Result 47
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6709 - accuracy: 0.7915
# Loss = 0.6709261536598206
# Test Accuracy = 0.7914692163467407
# Training Process 48
# 60/60 [==============================] - 37s 622ms/step - loss: 0.0478 - accuracy: 0.9963
# Test Result 48
# 20/20 [==============================] - 2s 106ms/step - loss: 0.6927 - accuracy: 0.7852
# Loss = 0.6926926374435425
# Test Accuracy = 0.7851500511169434
# Training Process 49
# 60/60 [==============================] - 38s 639ms/step - loss: 0.0361 - accuracy: 0.9984
# Test Result 49
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6921 - accuracy: 0.7741
# Loss = 0.6920901536941528
# Test Accuracy = 0.7740916013717651

# %%
for i in range(10):
    print("Training Process "+str(len(train_loss)))
    history = model.fit(train_X, train_Y.T,batch_size=32,epochs=1)
    print("Test Result "+str(len(train_loss)))
    preds = model.evaluate(test_X, test_Y.T)
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))
    train_loss.append(history.history["loss"][0])
    train_acc.append(history.history["accuracy"][0])
    test_loss.append(preds[0])
    test_acc.append(preds[1])
plt.plot(train_loss)
plt.show()
plt.plot(test_loss)
plt.show()
# Out:
# Training Process 50
# 60/60 [==============================] - 37s 620ms/step - loss: 0.0372 - accuracy: 0.9989
# Test Result 50
# 20/20 [==============================] - 2s 107ms/step - loss: 0.6957 - accuracy: 0.7788
# Loss = 0.6957069635391235
# Test Accuracy = 0.7788309454917908
# Training Process 51
# 60/60 [==============================] - 37s 624ms/step - loss: 0.0398 - accuracy: 0.9958
# Test Result 51
# 20/20 [==============================] - 2s 108ms/step - loss: 0.7024 - accuracy: 0.7867
# Loss = 0.7024321556091309
# Test Accuracy = 0.7867298722267151
# Training Process 52
# 60/60 [==============================] - 38s 630ms/step - loss: 0.0364 - accuracy: 0.9974
# Test Result 52
# 20/20 [==============================] - 2s 109ms/step - loss: 0.7252 - accuracy: 0.7820
# Loss = 0.7251726388931274
# Test Accuracy = 0.7819905281066895
# Training Process 53
# 60/60 [==============================] - 38s 635ms/step - loss: 0.0308 - accuracy: 0.9979
# Test Result 53
# 20/20 [==============================] - 2s 112ms/step - loss: 0.6978 - accuracy: 0.8009
# Loss = 0.6977943778038025
# Test Accuracy = 0.8009478449821472
# Training Process 54
# 60/60 [==============================] - 39s 644ms/step - loss: 0.0271 - accuracy: 0.9984
# Test Result 54
# 20/20 [==============================] - 2s 111ms/step - loss: 0.6955 - accuracy: 0.8009
# Loss = 0.6955093741416931
# Test Accuracy = 0.8009478449821472
# Training Process 55
# 60/60 [==============================] - 37s 611ms/step - loss: 0.0355 - accuracy: 0.9963
# Test Result 55
# 20/20 [==============================] - 2s 105ms/step - loss: 0.7250 - accuracy: 0.7757
# Loss = 0.72499680519104
# Test Accuracy = 0.7756714224815369
# Training Process 56
# 60/60 [==============================] - 37s 611ms/step - loss: 0.0580 - accuracy: 0.9857
# Test Result 56
# 20/20 [==============================] - 2s 111ms/step - loss: 0.8199 - accuracy: 0.7536
# Loss = 0.8199317455291748
# Test Accuracy = 0.7535545229911804
# Training Process 57
# 60/60 [==============================] - 38s 640ms/step - loss: 0.0268 - accuracy: 0.9995
# Test Result 57
# 20/20 [==============================] - 2s 118ms/step - loss: 0.7253 - accuracy: 0.7994
# Loss = 0.7252678871154785
# Test Accuracy = 0.7993680834770203
# Training Process 58
# 60/60 [==============================] - 39s 645ms/step - loss: 0.0279 - accuracy: 0.9974
# Test Result 58
# 20/20 [==============================] - 2s 113ms/step - loss: 0.7394 - accuracy: 0.7836
# Loss = 0.7394320368766785
# Test Accuracy = 0.7835702896118164
# Training Process 59
# 60/60 [==============================] - 39s 648ms/step - loss: 0.0230 - accuracy: 0.9989
# Test Result 59
# 20/20 [==============================] - 2s 115ms/step - loss: 0.7858 - accuracy: 0.7662
# Loss = 0.7858288288116455
# Test Accuracy = 0.7661927342414856

# %%
error = [0,0,0,0,0,0]
mislabel = np.zeros((6,6))
prediction = model.predict(test_X_re)
for i in range(test_X_re.shape[0]):
    if(test_Y_re[np.argmax(prediction,axis=1)[i],i] == 0):
        if(i<101):
            error[0] = error[0]+1
            mislabel[0][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<226):
            error[1] = error[1]+1
            mislabel[1][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<329):
            error[2] = error[2]+1
            mislabel[2][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<478):
            error[3] = error[3]+1
            mislabel[3][np.argmax(prediction,axis=1)[i]] += 1
        elif(i<599):
            error[4] = error[4]+1
            mislabel[4][np.argmax(prediction,axis=1)[i]] += 1
        else:
            error[5] = error[5]+1
            mislabel[5][np.argmax(prediction,axis=1)[i]] += 1
# Out:
# 20/20 [==============================] - 2s 111ms/step

# %%
total = np.array([101,125,103,149,121,34])
error = np.array(error)
error = np.divide(error,total)
print("% of mislabeled cardboard: "+str(error[0]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[0]))
print("% of mislabeled glass: "+str(error[1]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[1]))
print("% of mislabeled metal: "+str(error[2]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[2]))
print("% of mislabeled paper: "+str(error[3]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[3]))
print("% of mislabeled plastic: "+str(error[4]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[4]))
print("% of mislabeled trash: "+str(error[5]))
print("Mostly mislabeled as: "+str(np.argmax(mislabel,axis=0)[5]))
# Out:
# % of mislabeled cardboard: 0.10891089108910891
# Mostly mislabeled as: 2
# % of mislabeled glass: 0.152
# Mostly mislabeled as: 4
# % of mislabeled metal: 0.46601941747572817
# Mostly mislabeled as: 3
# % of mislabeled paper: 0.12080536912751678
# Mostly mislabeled as: 4
# % of mislabeled plastic: 0.3305785123966942
# Mostly mislabeled as: 1
# % of mislabeled trash: 0.35294117647058826
# Mostly mislabeled as: 2

# %%
f = open('train_loss_aug_p.txt', 'w')
for i in train_loss:
    f.write(str(i))
    f.write("\n")
f.close()

# %%
f = open('train_acc_aug_p.txt', 'w')
for i in train_acc:
    f.write(str(i))
    f.write("\n")
f.close()

# %%
f = open('test_acc_aug_p.txt', 'w')
for i in test_acc:
    f.write(str(i))
    f.write("\n")
f.close()
